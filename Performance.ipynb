# %% [markdown]
# # All Systems performance

# %%
from functions_ml import read_csv_file, plot_feature_importance
performance_path = "performance.csv"
feature_importance_path = "feature_importance.csv"

# %% [markdown]
# # DoS System 2 models

# %% [markdown]
# ## Binary (DoS (DoS and DDoS) or Benigh)

# %%
model_path = ".\\resultats\\DoS_2_models\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 6    GBoost           1.000000         1.000000            0.999999
# 1       XGB           1.000000         1.000000            0.999999
# 0        RF           1.000000         1.000000            1.000000
# 4       Cat           1.000000         1.000000            1.000000
# 7  Adaboost           1.000000         1.000000            1.000000
# 3        ET           1.000000         1.000000            1.000000
# 5     LIGHT           1.000000         1.000000            1.000000
# 8       MLP           0.999973         0.999909            0.999540
# 2        DT           1.000000         1.000000            1.000000
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 6     0.999999          0.999994        0.999976           0.999909
# 1     1.000000          0.999994        0.999961           0.999914
# 0     1.000000          0.999994        0.999973           0.999898
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All DoS and DDoS classes

# %%
model_path = ".\\resultats\\DoS_2_models\\All_classes\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 5        DT           1.000000         1.000000            1.000000
# 2       XGB           0.999902         0.999912            0.999936
# 0        RF           0.999983         0.999978            0.999989
# 1        ET           1.000000         1.000000            1.000000
# 3     LIGHT           0.529868         0.341591            0.380370
# 4  Adaboost           0.791984         0.645122            0.630099
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 5     1.000000          0.999661        0.995846           0.995685
# 2     0.999924          0.999584        0.994265           0.992981
# 0     0.999984          0.999131        0.992292           0.988353
# 1     1.000000          0.997346        0.980229           0.972252
# 3     0.352775          0.913611        0.652267           0.671212
# 4     0.625202          0.802192        0.713009           0.702917
#
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# # DoS System 3 models

# %% [markdown]
# ## Binary (DoS (DoS and DDoS) or Benigh)

# %%
model_path = ".\\resultats\\DoS_3_models\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 6    GBoost           1.000000         1.000000            0.999999
# 1       XGB           1.000000         1.000000            0.999999
# 0        RF           1.000000         1.000000            1.000000
# 4       Cat           1.000000         1.000000            1.000000
# 7  Adaboost           1.000000         1.000000            1.000000
# 3        ET           1.000000         1.000000            1.000000
# 5     LIGHT           1.000000         1.000000            1.000000
# 8       MLP           0.999973         0.999909            0.999540
# 2        DT           1.000000         1.000000            1.000000
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 6     0.999999          0.999994        0.999976           0.999909
# 1     1.000000          0.999994        0.999961           0.999914
# 0     1.000000          0.999994        0.999973           0.999898
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## Trinary (DoS or DDoS)(Remove Benigh rows)

# %%
model_path = ".\\resultats\\DoS_3_models\\Trinary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 3       XGB           1.000000         1.000000            1.000000
# 7    GBoost           0.999968         0.999933            0.999965
# 0        DT           1.000000         1.000000            1.000000
# 6  Adaboost           0.999928         0.999840            0.999930
# 1        RF           1.000000         1.000000            1.000000
# 4       Cat           0.999880         0.999707            0.999908
# 5     LIGHT           0.999949         0.999875            0.999962
# 2        ET           1.000000         1.000000            1.000000
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 3     1.000000          0.999908        0.999826           0.999877
# 7     0.999949          0.999904        0.999803           0.999888
# 0     1.000000          0.999896        0.999811           0.999854
# 6     0.999885          0.999867        0.999696           0.999876
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All DoS classes

# %%
model_path = ".\\resultats\\DoS_3_models\\DoS\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 2       XGB           1.000000         1.000000            1.000000
# 7    GBoost           1.000000         1.000000            1.000000
# 4       Cat           1.000000         1.000000            1.000000
# 5     LIGHT           1.000000         1.000000            1.000000
# 0        DT           1.000000         1.000000            1.000000
# 1        RF           1.000000         1.000000            1.000000
# 3        ET           1.000000         1.000000            1.000000
# 6  Adaboost           0.988003         0.974196            0.972019
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 2     1.000000          0.999949        0.999352           0.999805
# 7     1.000000          0.999943        0.999309           0.999481
# 4     1.000000          0.999898        0.998469           0.999269
# 5     1.000000          0.999889        0.998718           0.999200
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All DDoS classes

# %%
model_path = ".\\resultats\\DoS_3_models\\DDoS\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 2       XGB           1.000000         1.000000            1.000000
# 0        DT           1.000000         1.000000            1.000000
# 4       Cat           0.999942         0.999956            0.999958
# 1        RF           1.000000         1.000000            1.000000
# 3        ET           1.000000         1.000000            1.000000
# 6  Adaboost           0.831995         0.715633            0.696793
# 5     LIGHT           0.620720         0.420461            0.440193
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 2     1.000000          0.999907        0.997951           0.998336
# 0     1.000000          0.999755        0.996045           0.995139
# 4     0.999957          0.999740        0.994380           0.992758
# 1     1.000000          0.999393        0.993630           0.988402
# 3     1.000000          0.998669        0.987064           0.975746
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# # Authentification Attacks System

# %% [markdown]
# ## Binary (Auth or Benigh)

# %%
model_path = ".\\resultats\\Auth\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                       Model  Accuracy Training  Recall Training  \
# 9     Voting (Cat, XGB, RF)           0.993540         0.994797
# 10            Bagging (Cat)           0.989455         0.990524
# 4                       Cat           0.990150         0.991135
# 11  Stacking (Cat, XGB, RF)           0.994851         0.995248
# 3                       XGB           0.988061         0.988909
# 1                        RF           0.999995         0.999994
# 5                     LIGHT           0.983138         0.983981
# 2                        ET           0.999997         0.999996
# 0                        DT           0.999997         0.999995
# 6                    GBoost           0.974160         0.973539
# 7                  Adaboost           0.968011         0.966038
# 8                       MLP           0.962940         0.961238
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All Auth classes

# %%
model_path = ".\\resultats\\Auth\\All_classes\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                          Model  Accuracy Training  Recall Training  \
# 9     Voting (Cat, XGB, LIGHT)           0.993822         0.971818
# 10               Bagging (XGB)           0.994257         0.968562
# 3                          XGB           0.995024         0.976153
# 5                        LIGHT           0.969947         0.951957
# 4                          Cat           0.992263         0.950503
# 1                           RF           0.999998         0.999978
# 11  Stacking (Cat, LIGHT, XGB)           0.977392         0.934748
# 6                       GBoost           0.983537         0.904020
# 0                           DT           0.999999         0.999998
# 2                           ET           0.999999         0.999999
# 8                          MLP           0.915010         0.758196
# 7                     Adaboost           0.802470         0.731473
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# # Recon System

# %% [markdown]
# ## Binary (Recon or Benigh)

# %%
model_path = ".\\resultats\\Recon\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                       Model  Accuracy Training  Recall Training  \
# 10            Bagging (Cat)           0.971967         0.950460
# 9     Voting (Cat, XGB, RF)           0.981404         0.965368
# 11  Stacking (Cat, XGB, RF)           0.983259         0.974228
# 4                       Cat           0.972429         0.951546
# 3                       XGB           0.970008         0.948019
# 1                        RF           0.999978         0.999972
# 5                     LIGHT           0.962114         0.935232
# 2                        ET           0.999996         0.999998
# 6                    GBoost           0.952581         0.921199
# 7                  Adaboost           0.949674         0.913846
# 0                        DT           0.999985         0.999987
# 8                       MLP           0.922709         0.869240
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All Recon classes

# %%
model_path = ".\\resultats\\Recon\\All_classes\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                          Model  Accuracy Training  Recall Training  \
# 10               Bagging (XGB)           0.931769         0.927895
# 9     Voting (Cat, XGB, LIGHT)           0.927547         0.933455
# 3                          XGB           0.934831         0.939892
# 5                        LIGHT           0.920457         0.938931
# 11  Stacking (Cat, LIGHT, XGB)           0.918469         0.890004
# 4                          Cat           0.918952         0.870929
# 1                           RF           0.992818         0.993519
# 6                       GBoost           0.870552         0.838357
# 0                           DT           0.995183         0.995172
# 2                           ET           0.997790         0.997405
# 8                          MLP           0.751677         0.628650
# 7                     Adaboost           0.691761         0.644241
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# # Mirai System

# %% [markdown]
# ## Binary (Mirai or Benigh)

# %%
model_path = ".\\resultats\\Mirai\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 6    GBoost           1.000000         1.000000            0.999999
# 7  Adaboost           1.000000         1.000000            1.000000
# 0       XGB           0.999999         0.999999            0.999998
# 2        RF           1.000000         1.000000            1.000000
# 3        ET           1.000000         1.000000            1.000000
# 4       Cat           0.999985         0.999987            0.999976
# 5     LIGHT           1.000000         1.000000            1.000000
# 8       MLP           0.999986         0.999990            0.999977
# 1        DT           1.000000         1.000000            1.000000
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 6     0.999999          0.999998        0.999999           0.999997
# 7     1.000000          0.999998        0.999999           0.999997
# 0     0.999999          0.999995        0.999993           0.999995
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All Mirai classes

# %%
model_path = ".\\resultats\\Mirai\\All_classes\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#       Model  Accuracy Training  Recall Training  Precision Training  \
# 0       XGB           1.000000         1.000000            1.000000
# 5     LIGHT           1.000000         1.000000            1.000000
# 6    GBoost           0.999992         0.999992            0.999992
# 4       Cat           1.000000         1.000000            1.000000
# 1        DT           1.000000         1.000000            1.000000
# 2        RF           1.000000         1.000000            1.000000
# 3        ET           1.000000         1.000000            1.000000
# 7  Adaboost           0.995605         0.995783            0.995215
# 8       MLP           0.980256         0.979370            0.980149
#
#    F1 Training  Accuracy Testing  Recall Testing  Precision Testing  \
# 0     1.000000          0.999894        0.999895           0.999888
# 5     1.000000          0.999891        0.999893           0.999885
# 6     0.999992          0.999891        0.999893           0.999886
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# # Web System

# %% [markdown]
# ## Binary (Web or Benigh)

# %%
model_path = ".\\resultats\\Web\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                       Model  Accuracy Training  Recall Training  \
# 9     Voting (Cat, XGB, RF)           0.998245         0.960417
# 10            Bagging (Cat)           0.996474         0.923539
# 3                       XGB           0.997142         0.939562
# 11  Stacking (Cat, XGB, RF)           0.999801         0.996754
# 4                       Cat           0.997470         0.945459
# 1                        RF           1.000000         1.000000
# 5                     LIGHT           0.994353         0.890188
# 6                    GBoost           0.991698         0.823348
# 7                  Adaboost           0.989832         0.827434
# 2                        ET           1.000000         1.000000
# 0                        DT           1.000000         1.000000
# 8                       MLP           0.984485         0.678874
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All Web classes

# %%
model_path = ".\\resultats\\Web\\All_classes\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                          Model  Accuracy Training  Recall Training  \
# 9     Voting (Cat, XGB, LIGHT)           0.999736         0.999699
# 10             Bagging (LIGHT)           0.996474         0.995959
# 5                        LIGHT           0.999824         0.999809
# 3                          XGB           0.999912         0.999932
# 4                          Cat           0.987218         0.983968
# 6                       GBoost           0.854637         0.827617
# 11  Stacking (Cat, LIGHT, XGB)           0.881700         0.866203
# 1                           RF           1.000000         1.000000
# 0                           DT           1.000000         1.000000
# 2                           ET           1.000000         1.000000
# 7                     Adaboost           0.618036         0.532928
# 8                          MLP           0.534379         0.440642
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# # Web and Dictionary brute force System

# %% [markdown]
# ## Binary (Web and Dictionary brute force or Benigh)

# %%
model_path = ".\\resultats\\Web_and_Dict\\Binary\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                       Model  Accuracy Training  Recall Training  \
# 9     Voting (Cat, XGB, RF)           0.996532         0.949226
# 10            Bagging (Cat)           0.993805         0.914292
# 3                       XGB           0.994411         0.925391
# 11  Stacking (Cat, XGB, RF)           0.999190         0.992626
# 4                       Cat           0.995319         0.935586
# 1                        RF           0.999996         0.999944
# 5                     LIGHT           0.990554         0.884412
# 6                    GBoost           0.987308         0.824706
# 7                  Adaboost           0.985428         0.822022
# 0                        DT           1.000000         1.000000
# 2                        ET           1.000000         1.000000
# 8                       MLP           0.978243         0.711352
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)

# %% [markdown]
# ## All Web and Dictionary brute force classes

# %%
model_path = ".\\resultats\\Web_and_Dict\\All_classes\\"
read_csv_file(performance_path, model_path).sort_values(by=['Total rows', 'Accuracy Testing', 'Recall Testing', 'Precision Testing', 'F1 Testing'], ascending=False).head(20)
# Out:
#                          Model  Accuracy Training  Recall Training  \
# 9     Voting (Cat, XGB, LIGHT)           0.998368         0.998151
# 10               Bagging (XGB)           0.993246         0.991220
# 3                          XGB           0.999381         0.999258
# 5                        LIGHT           0.998874         0.998849
# 4                          Cat           0.968089         0.957050
# 11  Stacking (Cat, LIGHT, XGB)           0.906067         0.857379
# 1                           RF           1.000000         1.000000
# 6                       GBoost           0.839712         0.788421
# 0                           DT           1.000000         1.000000
# 2                           ET           1.000000         1.000000
# 7                     Adaboost           0.599167         0.488177
# 8                          MLP           0.578850         0.437922
#
#     Precision Training  F1 Training  Accuracy Testing  Recall Testing  \
# ...

# %% [markdown]
# ### Feature Importance

# %%
average_importance_df = read_csv_file(feature_importance_path, model_path)
plot_feature_importance(average_importance_df)
# average_importance_df.head(average_importance_df.size)
